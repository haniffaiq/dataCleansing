# %%
import json
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from pandas import json_normalize

# %%
df = pd.read_excel('data-set.xlsx', sheet_name='Data Aktifitas', header=None)
df = pd.DataFrame(df)
df.drop([0,1,2], inplace = True)
df = df.dropna(how = 'all')
#df = df.apply(lambda x: pd.Series(x.dropna().values))

# %%
df
# Out:
#         0                  1      2             3                      4   \
# 3      No.            Tanggal  Nomor        ATM ID                 Lokasi
# 4        1       16 Juli 2020  88826      ATM00001         RUANG UAT DPTI
# 5        2      03 Maret 2020  86010  ATM120029008         PLN AHMAD YANI
# 6      NaN                NaN    NaN           NaN                    NaN
# 7        3  02 September 2020  90681  ATM120044005           GRAHA ENERGY
# ...    ...                ...    ...           ...                    ...
# 3661  3168       01 Juli 2020  88730   ATM20099005  BSB CAPEM KRAMAT JATI
# 3662  3169   09 November 2020  90731   ATM20099007    CAPEM BSD TANGERANG
# 3663  3170        27 Mei 2020  88655   ATM20099009   BSB  RS JATISAMPURNA
# 3664   NaN                NaN    NaN           NaN                    NaN
# 3665  3171   22 Februari 2020  88642    ATM2013001                    NaN
#
#                  5                        6   \
# ...

# %%
df.to_csv (r'TempDataAktifitas.csv', index=False, header=False)

# %%
data = pd.read_csv('TempDataAktifitas.csv')
data = pd.DataFrame(data)

print(data.columns)
# Out:
# Index(['No.', 'Tanggal', 'Nomor', 'ATM ID', 'Lokasi', 'Jenis Layanan',
#        'Laporan Kerusakan', 'Pekerjaan Dilakukan', 'Nomor Tiket',
#        'Penggantian Sparepart', 'Jumlah Part', 'Status', 'CSE', 'Pilihan'],
#       dtype='object')

# %%
def isnan(value):
    try:
        import math
        return math.isnan(float(value))
    except:
        return False

# %%
kolom = ['No.', 'Tanggal', 'Nomor', 'ATM ID', 'Lokasi', 'Jenis Layanan','Laporan Kerusakan', 'Pekerjaan Dilakukan', 'Nomor Tiket','Status', 'CSE', 'Pilihan']
for i in range (len(data)):
    
    #print(type(data.iloc[i]['Tanggal']))
    x = data.iloc[i]['Tanggal']
    if(isnan(x)):
        idx = i
        beforeNaN = i - 1
        for j in range(len(kolom)):
            
            data.at[idx, kolom[j]] = data.iloc[beforeNaN][kolom[j]]

# %%
data
# Out:
#          No.            Tanggal    Nomor        ATM ID                 Lokasi  \
# 0        1.0       16 Juli 2020  88826.0      ATM00001         RUANG UAT DPTI
# 1        2.0      03 Maret 2020  86010.0  ATM120029008         PLN AHMAD YANI
# 2        2.0      03 Maret 2020  86010.0  ATM120029008         PLN AHMAD YANI
# 3        3.0  02 September 2020  90681.0  ATM120044005           GRAHA ENERGY
# 4        4.0  09 September 2020  89466.0  ATM120047014                    NaN
# ...      ...                ...      ...           ...                    ...
# 3657  3168.0       01 Juli 2020  88730.0   ATM20099005  BSB CAPEM KRAMAT JATI
# 3658  3169.0   09 November 2020  90731.0   ATM20099007    CAPEM BSD TANGERANG
# 3659  3170.0        27 Mei 2020  88655.0   ATM20099009   BSB  RS JATISAMPURNA
# 3660  3170.0        27 Mei 2020  88655.0   ATM20099009   BSB  RS JATISAMPURNA
# 3661  3171.0   22 Februari 2020  88642.0    ATM2013001                    NaN
#
# ...

# %%
for i in range (len(data)):
    #print(type(data.iloc[i]['Tanggal']))
    data.at[i, 'No.'] = int(data.iloc[i]['No.'])
data
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
data.to_csv('NewDataAktifitas.csv', index=False)
